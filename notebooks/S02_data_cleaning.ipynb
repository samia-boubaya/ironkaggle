# %%
cols_to_convert = [
    "MSSubClass",   # house type code
    "OverallQual",  # quality rating (ordinal)
    "OverallCond",  # condition rating (ordinal)
    "MoSold",       # month sold
    "YrSold"        # year sold
]

# Convert columns type to object 
for col in cols_to_convert:
    df[col] = df[col].astype("object")

# %% [markdown]
# <hr>
#
# # 🧫 DATA CLEANING 🧫
#
# <style>
# h1 {
#     text-align: center;
#     color: blue;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <hr>

# %% [markdown]
# - This dataset is made for Machine Learning and needs to be reformatted to be used for analysis and plotting.

# %% [markdown]
# <hr>
#
# ### 📂 IMPORTs
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: red;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
import seaborn as sns

plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)

# %% [markdown]
# <hr>
#
# ## 1️⃣ STANDARD COLUMNS
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: darkblue;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# <hr>
#
# ### 🔲 DISPLAY STANDARDIZED DATASET
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: red;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %%
# Display df DataFrame
print("Online Shoppers Intention Dataset:")
display(df.head(10))
print("Main Dataset Shape:", df.shape[0], "rows and", df.shape[1], "columns\n")

# Display data types & missing values of each column in df
print("Data Types & Missing Values of Each Column:")
display(df.info())

# %% [markdown]
# <hr>
#
# ## 2️⃣ INVALID VALUES
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: darkblue;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %%
# print data types and unique values count for each column in df
print(f"\nData types check:")
for col in df.columns:
    dtype = df[col].dtype
    unique_vals = df[col].nunique()
    print(f"  ➡️{col:<25} {str(dtype):<10} [{unique_vals}] unique values")

# %%
# Loop through each column and print unique values
print(100 * "-")
for col in df.columns:
    unique_vals = df[col].unique()
    print(f"➡️ {col} ({len(unique_vals)}) 🧾 unique values:")
    print(f"{unique_vals}")
    print(100 * "-")

# %% [markdown]
# <hr>
#
# ## 3️⃣ DATA TYPES
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: darkblue;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %%
# print data types for each column in df
print(f"\nData types of each column:")
for col in df.columns:
    dtype = df[col].dtype
    unique_vals = df[col].nunique()
    # print column name and data type
    print(f"  ➡️{col:<25} {str(dtype):<10}")

# %% [markdown]
# <hr>
#
# ### Convert datatypes:
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: red;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %% [markdown]
# <hr>
#
# ### Check datatypes after conversion:
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: red;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %%
# print data types for each column in df
print(f"\nData types of each column:")
for col in df.columns:
    dtype = df[col].dtype
    unique_vals = df[col].nunique()
    # print column name and data type
    print(f"  ➡️{col:<25} {str(dtype):<10}")

# %% [markdown]
# <hr>
#
# ## 4️⃣ NULL VALUES
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: darkblue;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %%
# Loop through each column and print the number of nulls in each column
for col in df.columns:
    null_count = df[col].isnull().sum()
    print(f"[{col}]: [{null_count}] null values")

print(70*"-")
df.info()

# %% [markdown]
# <hr>
#
# ## 5️⃣ DUPLICATE VALUES
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: darkblue;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %%
# DISPLAY DUPLICATE ROWS
# Check for duplicate rows in the DataFrame -----------------------------------------
duplicate_rows = df[df.duplicated()]

# Print the number of duplicate rows
print(f"Number of duplicate rows: {duplicate_rows.shape[0]}")

# Display the duplicate rows if any exist
if not duplicate_rows.empty:
    print("\nDuplicate rows:")
    display(duplicate_rows)
else:
    print("\nNo duplicate rows found.")

# %% [markdown]
# <hr>
#
# ## SAVE CLEAN CSV
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: darkblue;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %%
# save clean dataset in a new CSV file
train.to_csv("../data/processed/X_train.csv", index=False)
test.to_csv("../data/processed/X_test_clean.csv", index=False)
