# %% [markdown]
# <hr>
#
# # 🔍 DATA EXPLORATION 🔍
#
# <style>
# h1 {
#     text-align: center;
#     color: green;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <hr>

# %% [markdown]
# <hr>
#
# ### 📂 IMPORTs
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: red;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %%
# import necessary libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from IPython.display import display
import seaborn as sns

plt.style.use('ggplot')
pd.set_option('display.max_columns', 200)

# %% [markdown]
# <hr>
#
# ### 🔻 LOAD & DISPLAY RAW DATASET
#
#
# <style>
# h1 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h2 {
#     text-align: left;
#     color: red;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h3 {
#     text-align: left;
#     color: black;
#     font-weight: bold;
# }
# </style>
#
# <style>
# h4 {
#     text-align: center;
#     color: black;
#     font-weight: bold;
# }
# </style>
# <hr>

# %%
import pandas as pd
from IPython.display import display

# Load train and test sets in dataframes
df_train_train = pd.read_csv("../data/raw/train.csv")
df_train_test = pd.read_csv("../data/raw/test.csv")

# Display df_train DataFrame
print("Train Dataset:")
display(df_train_train.head(10))
print("Main Dataset Shape:", df_train.shape[0], "rows and", df_train.shape[1], "columns\n")

# Display data types & missing values of each column in df_train
print("Data Types & Missing Values of Each Column:")
display(df_train_train.info())

# Loop through each column and print unique values
for col in df_train.columns:
    unique_vals = df_train[col].unique()
    print(f"Column: {col}")
    print(f"Unique values ({len(unique_vals)}): {unique_vals}\n")

print(f"\nData types check:")
for col in df_train.columns:
    dtype = df_train[col].dtype
    unique_vals = df_train[col].nunique()
    print(f"  ➡️{col:<25} {str(dtype):<10} [{unique_vals}] unique values")
